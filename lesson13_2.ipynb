# %%
url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&'

# %%
import requests

response = requests.get(url)

# %%
if response.status_code == 200:
    print("下載成功")
    print(response.text)
# Out:
# 下載成功
# <?xml version="1.0" encoding="UTF-8"?>
# <cwbopendata xmlns="urn:cwb:gov:tw:cwbcommon:0.1">
#     <identifier >dd480d72-95f9-d4ab-851d-3db3de5f041e</identifier>
#     <sender >weather@cwb.gov.tw</sender>
#     <sent >2023-09-03T10:18:02+08:00</sent>
#     <status >Actual</status>
#     <msgType >Issue</msgType>
#     <source >MFC</source>
#     <dataid >C0032-001</dataid>
#     <scope >Public</scope>
#     <dataset >
#         <datasetInfo>
#             <datasetDescription>三十六小時天氣預報</datasetDescription>
#             <issueTime>2023-09-03T11:00:00+08:00</issueTime>
#             <update>2023-09-03T10:18:02+08:00</update>
# </datasetInfo>
#         <location>
#             <locationName>臺北市</locationName>
#             <weatherElement>
#                 <elementName>Wx</elementName>
#                 <time>
#                     <startTime>2023-09-03T12:00:00+08:00</startTime>
#                     <endTime>2023-09-03T18:00:00+08:00</endTime>
#                     <parameter>
# ...
